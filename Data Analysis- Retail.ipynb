# %%
import pandas as pd
df1 = pd.read_csv("/content/Features data set.csv")
df1.head()
# Out:
#    Store        Date  Temperature  ...         CPI  Unemployment  IsHoliday
# 0      1  05/02/2010        42.31  ...  211.096358         8.106      False
# 1      1  12/02/2010        38.51  ...  211.242170         8.106       True
# 2      1  19/02/2010        39.93  ...  211.289143         8.106      False
# 3      1  26/02/2010        46.63  ...  211.319643         8.106      False
# 4      1  05/03/2010        46.50  ...  211.350143         8.106      False
#
# [5 rows x 12 columns]

# %%
df1.describe()
# Out:
#              Store  Temperature  ...          CPI  Unemployment
# count  8190.000000  8190.000000  ...  7605.000000   7605.000000
# mean     23.000000    59.356198  ...   172.460809      7.826821
# std      12.987966    18.678607  ...    39.738346      1.877259
# min       1.000000    -7.290000  ...   126.064000      3.684000
# 25%      12.000000    45.902500  ...   132.364839      6.634000
# 50%      23.000000    60.710000  ...   182.764003      7.806000
# 75%      34.000000    73.880000  ...   213.932412      8.567000
# max      45.000000   101.950000  ...   228.976456     14.313000
#
# [8 rows x 10 columns]

# %%
df1.shape
# Out:
# (8190, 12)

# %%
print(f'Temperature: {df1.Temperature.count()}')
print(f'Markdown1: {df1.MarkDown1.count()}')
print(f'Markdown2: {df1.MarkDown2.count()}')
print(f'Markdown3: {df1.MarkDown3.count()}')
print(f'Markdown4: {df1.MarkDown4.count()}')
print(f'Markdown5: {df1.MarkDown5.count()}')
# Out:
# Temperature: 8190
# Markdown1: 4032
# Markdown2: 2921
# Markdown3: 3613
# Markdown4: 3464
# Markdown5: 4050

# %%
print(f'Store: {df1.Store.nunique()}')
print(f'Temperature: {df1.Temperature.nunique()}')
# Out:
# Store: 45
# Temperature: 4178

# %%
print(f'Store: {df1.Store.dtype}')
print(f'Temperature: {df1.Temperature.dtype}')
print(f'Fuel price: {df1.Fuel_Price.dtype}')
print(f'CPI: {df1.CPI.dtype}')
print(f'Unemployment: {df1.Unemployment.dtype}')
# Out:
# Store: int64
# Temperature: float64
# Fuel price: float64
# CPI: float64
# Unemployment: float64

# %%
print(f'Minimum:{df1.Temperature.min()}')
print(f'Maximum:{df1.Temperature.max()}')
print(f'First Quantile: {df1.Temperature.quantile(0.25)}')
print(f'Second Quantile: {df1.Temperature.quantile(0.50)}')
print(f'Third Quantile: {df1.Temperature.quantile(0.75)}')
print(f'Mean: {df1.Temperature.mean()}')
print(f'Median: {df1.Temperature.median()}')
print(f'Mode: {df1.Temperature.mode()}')
print(f'Standard Deviation: {df1.Temperature.std()}')
# Out:
# Minimum:-7.29
# Maximum:101.95
# First Quantile: 45.902499999999996
# Second Quantile: 60.71
# Third Quantile: 73.88
# Mean: 59.35619780219781
# Median: 60.71
# Mode: 0    50.43
# 1    70.28
# dtype: float64
# Standard Deviation: 18.678606848907176

# %%
print(f'Minimum:{df1.Fuel_Price.min()}')
print(f'Maximum:{df1.Fuel_Price.max()}')
print(f'First Quantile: {df1.Fuel_Price.quantile(0.25)}')
print(f'Second Quantile: {df1.Fuel_Price.quantile(0.50)}')
print(f'Third Quantile: {df1.Fuel_Price.quantile(0.75)}')
print(f'Mean: {df1.Fuel_Price.mean()}')
print(f'Median: {df1.Fuel_Price.median()}')
print(f'Mode: {df1.Fuel_Price.mode()}')
print(f'Standard Deviation: {df1.Fuel_Price.std()}')
# Out:
# Minimum:2.472
# Maximum:4.468
# First Quantile: 3.041
# Second Quantile: 3.513
# Third Quantile: 3.743
# Mean: 3.4059918192918217
# Median: 3.513
# Mode: 0    3.417
# 1    3.638
# dtype: float64
# Standard Deviation: 0.43133657110071605

# %%
df1.corr()
# Out:
#                      Store  Temperature  ...  Unemployment     IsHoliday
# Store         1.000000e+00    -0.020566  ...      0.221153 -4.186667e-16
# Temperature  -2.056605e-02     1.000000  ...      0.150890 -1.619056e-01
# Fuel_Price    6.668205e-02     0.101354  ...     -0.033360 -7.823797e-02
# MarkDown1    -1.369671e-01    -0.124979  ...      0.020501  1.526209e-01
# MarkDown2    -4.422331e-02    -0.321888  ...     -0.001692  2.994476e-01
# MarkDown3    -3.327926e-02    -0.077552  ...     -0.003464  4.452239e-01
# MarkDown4    -5.173997e-03    -0.064194  ...      0.021905  1.348406e-01
# MarkDown5    -1.196994e-02    -0.003241  ...      0.031847 -2.462956e-02
# CPI          -2.092824e-01     0.164426  ...     -0.303110  1.008430e-03
# Unemployment  2.211525e-01     0.150890  ...      1.000000 -2.644393e-03
# IsHoliday    -4.186667e-16    -0.161906  ...     -0.002644  1.000000e+00
#
# [11 rows x 11 columns]
